# %%
Tau: 0.38000000000000006
Optimal interventions: [ 29  48  49  61 117 119 155]
Total impact: 110.5539329205278

Tau: 0.39000000000000007
Optimal interventions: [ 29  48  49  61 117 122 155]
Total impact: 110.5781957599831

Tau: 0.4000000000000001
Optimal interventions: [ 29  48  49  61 117 122 155]
Total impact: 110.5781957599831

Tau: 0.4100000000000001
Optimal interventions: [ 48  49  61  76 117 122 155]
Total impact: 110.61290174698065

Tau: 0.4200000000000001
Optimal interventions: [ 48  49  61  76 117 122 155]
Total impact: 110.61290174698065

Tau: 0.4300000000000001
Optimal interventions: [ 48  49  61 117 122 139 155]
Total impact: 110.60297492267065

Tau: 0.4400000000000001
Optimal interventions: [ 29  48  61  76 122 139 155]
Total impact: 110.93414929885301

Tau: 0.4500000000000001
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.46000000000000013
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.47000000000000014
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.48000000000000015
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.49000000000000016
Optimal interventions: [ 36  48  61  76  82 122 155]
Total impact: 110.95686415834582

Tau: 0.5000000000000002
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.5100000000000002
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.5200000000000002
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.5300000000000002
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.5400000000000003
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.5500000000000003
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.5600000000000003
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.5700000000000003
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.5800000000000003
Optimal interventions: [ 29  48  61  76 122 139 155]
Total impact: 110.93414929885301

Tau: 0.5900000000000003
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.6000000000000003
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.6100000000000003
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.6200000000000003
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.6300000000000003
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.6400000000000003
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.6500000000000004
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.6600000000000004
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.6700000000000004
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.6800000000000004
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.6900000000000004
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.7000000000000004
Optimal interventions: [ 29  48  61  76 122 139 155]
Total impact: 110.93414929885301

Tau: 0.7100000000000004
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.7200000000000004
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.7300000000000004
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.7400000000000004
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982

Tau: 0.7500000000000004
Optimal interventions: [ 36  48  61  76 122 139 155]
Total impact: 110.96131229511982
# Out:
#   Cell In[1], line 2
#     Optimal interventions: [ 29  48  49  61 117 119 155]
#             ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt

# Tau values
tau_values = [0.38, 0.39, 0.40, 0.41, 0.42, 0.43, 0.44, 0.45, 0.46, 0.47, 0.48, 0.49, 0.50]

# Total Impact values
total_impact = [
    110.5539329205278,
    110.5781957599831,
    110.5781957599831,
    110.61290174698065,
    110.61290174698065,
    110.60297492267065,
    110.93414929885301,
    110.96131229511982,
    110.96131229511982,
    110.96131229511982,
    110.96131229511982,
    110.95686415834582,
    110.96131229511982
]

# Unconstrained impact
unconstrained_impact = 110.96131229511886


# Unconstrained impact
unconstrained_impact = 110.96131229511886

# Plot
plt.figure(figsize=(8, 5))
plt.plot(tau_values, total_impact, marker='o', linestyle='-', label="Total Impact")

# Add a horizontal dashed line
plt.axhline(y=unconstrained_impact, color='r', linestyle='--', label="Unconstrained Impact")

# Annotate the unconstrained impact value
plt.text(0.361, unconstrained_impact + 0.006, f"{unconstrained_impact:.3f}", 
         color='r', fontsize=10, verticalalignment='bottom')

# Labels and title
plt.xlabel("Tau")
plt.ylabel("Total Impact")
plt.title(" How Total Impact varies with Tau")
plt.legend()
plt.grid(True)

# save the plot 
plt.savefig("results/tau_vs_total_impact.png")

# Show the plot
plt.show()

# %%
race_columns = ['registered_A', 'registered_B', 'registered_C', 
                'registered_D', 'registered_E', 'registered_F', 'registered_G']

df['majority_race'] = df[race_columns].idxmax(axis=1).str.replace('registered_', '')

# %%
df = pd.read_csv('GA_features.csv')

# %%
df['majority_race'].value_counts()
# Out:
# majority_race
# B    132
# A     27
# Name: count, dtype: int64

# %%
df['registered_A']
# Out:
# 0       2162
# 1        913
# 2        900
# 3        929
# 4      10988
#        ...
# 154     2200
# 155     1318
# 156     2682
# 157     2611
# 158     3563
# Name: registered_A, Length: 159, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('GA_features.csv')

# Race columns
race_columns = ['registered_A', 'registered_B', 'registered_C', 
                'registered_D', 'registered_E', 'registered_F', 'registered_G']

# Add a column for the majority race based on the maximum registration count
df['majority_race'] = df[race_columns].idxmax(axis=1).str.replace('registered_', '')

# Interventions per tau (actual interventions)
interventions_per_tau = {
    0.38: [29, 48, 49, 61, 117, 119, 155],
    0.39: [29, 48, 49, 61, 117, 122, 155],
    0.40: [29, 48, 49, 61, 117, 122, 155],
    0.41: [48, 49, 61, 76, 117, 122, 155],
    0.42: [48, 49, 61, 76, 117, 122, 155],
    0.43: [48, 49, 61, 117, 122, 139, 155],
    0.44: [29, 48, 61, 76, 122, 139, 155],
    0.45: [36, 48, 61, 76, 122, 139, 155],
    0.46: [36, 48, 61, 76, 122, 139, 155],
    0.47: [36, 48, 61, 76, 122, 139, 155],
    0.48: [36, 48, 61, 76, 122, 139, 155],
    0.49: [36, 48, 61, 76, 82, 122, 155],
    0.50: [36, 48, 61, 76, 122, 139, 155]
}

# Function to count the number of interventions per majority race for each tau
def count_majority_race_interventions(tau, interventions, df):
    majority_race_counts = {'Black': 0, 'White': 0}
    
    # Get the majority race for each county in the intervention list
    for county_id in interventions:
        majority_race = df.loc[county_id, 'majority_race']
        if majority_race == 'A':
            majority_race_counts['Black'] += 1
        elif majority_race == 'B':
            majority_race_counts['White'] += 1
    
    return majority_race_counts

# Create a dictionary to store the results
race_intervention_counts = {tau: count_majority_race_interventions(tau, counties, df) 
                            for tau, counties in interventions_per_tau.items()}

# Convert the race_intervention_counts dictionary into a DataFrame for plotting
race_intervention_df = pd.DataFrame(race_intervention_counts).T

# Plotting the results
fig, ax = plt.subplots(figsize=(10, 6), dpi=300)

# Bar plot for each tau value (side-by-side bars for Black and White)
race_intervention_df.plot.bar(ax=ax, stacked=False, color=['#1f77b4', '#aec7e8'], 
                              edgecolor='white', alpha=0.8)

# Adding labels, title, and formatting
ax.set_ylabel('Number of Interventions', fontsize=12)
ax.set_xlabel('Tau', fontsize=12)
ax.set_title('Number of Interventions Allocated to Majority Race by Tau', fontsize=14)
ax.legend(title="Majority Race", loc='upper left', fontsize=10, labels=["Black", "White"])


# Rotate the x-axis labels for better readability
ax.set_xticklabels([f'{tau:.2f}' for tau in race_intervention_df.index], rotation=0, ha='center')

# Adding a grid to make it more readable
ax.grid(axis='y', linestyle='--', linewidth=0.5)

# Adjust the layout
plt.tight_layout()
plt.savefig('results/majority_race_blue.png')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('GA_features.csv')

# Race columns
race_columns = ['registered_A', 'registered_B', 'registered_C', 
                'registered_D', 'registered_E', 'registered_F', 'registered_G']

# Add a column for the majority race based on the maximum registration count
df['majority_race'] = df[race_columns].idxmax(axis=1).str.replace('registered_', '')

# Interventions per tau (actual interventions)
interventions_per_tau = {
    0.38: [29, 48, 49, 61, 117, 119, 155],
    0.39: [29, 48, 49, 61, 117, 122, 155],
    0.40: [29, 48, 49, 61, 117, 122, 155],
    0.41: [48, 49, 61, 76, 117, 122, 155],
    0.42: [48, 49, 61, 76, 117, 122, 155],
    0.43: [48, 49, 61, 117, 122, 139, 155],
    0.44: [29, 48, 61, 76, 122, 139, 155],
    0.45: [36, 48, 61, 76, 122, 139, 155],
    0.46: [36, 48, 61, 76, 122, 139, 155],
    0.47: [36, 48, 61, 76, 122, 139, 155],
    0.48: [36, 48, 61, 76, 122, 139, 155],
    0.49: [36, 48, 61, 76, 82, 122, 155],
    0.50: [36, 48, 61, 76, 122, 139, 155]
}

# Function to count the number of interventions per majority race for each tau
def count_majority_race_interventions(tau, interventions, df):
    majority_race_counts = {'Black': 0, 'White': 0}
    
    # Get the majority race for each county in the intervention list
    for county_id in interventions:
        majority_race = df.loc[county_id, 'majority_race']
        if majority_race == 'A':
            majority_race_counts['Black'] += 1
        elif majority_race == 'B':
            majority_race_counts['White'] += 1
    
    return majority_race_counts

# Create a dictionary to store the results
race_intervention_counts = {tau: count_majority_race_interventions(tau, counties, df) 
                            for tau, counties in interventions_per_tau.items()}

# Convert the race_intervention_counts dictionary into a DataFrame for plotting
race_intervention_df = pd.DataFrame(race_intervention_counts).T

# Plotting the results
fig, ax = plt.subplots(figsize=(10, 6), dpi=300)

# Bar plot for each tau value (side-by-side bars for Black and White)
# Lighter shades of purple for Black and White
race_intervention_df.plot.bar(ax=ax, stacked=False, 
                              color=['#b39ddb', '#d1c4e9'], 
                              edgecolor='white', width=0.8)

# Adding labels, title, and formatting
ax.set_ylabel('Number of Interventions', fontsize=12)
ax.set_xlabel('Tau', fontsize=12)
ax.set_title('Number of Interventions Allocated to Majority Race by Tau', fontsize=14)
ax.legend(title="Majority Race", loc='upper left', fontsize=10, labels=["Black", "White"])

# Rotate the x-axis labels for better readability
ax.set_xticklabels([f'{tau:.2f}' for tau in race_intervention_df.index], rotation=0, ha='right')

# Adding a grid to make it more readable
ax.grid(axis='y', linestyle='--', linewidth=0.5)

# Adjust the layout
plt.tight_layout()
plt.savefig('results/majority_race_purple.png')
plt.show()
